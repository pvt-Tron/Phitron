# %%
# Strings in Python
prompt = "What's your name?"
print(prompt)
print(type(prompt))
name = input()

print(prompt[0])
print(prompt[3])
print(name[0])
print(name[3])
prompt = "Tell me about Yourself: "
# infos = input(prompt).split()
infos = input(prompt)

# ---  Slice  ---

nums = [10, 20, 30, 40, 50, 60]

print(nums[1:4]) # middle slice
print(nums[-3:]) # slice last 3
print(nums[::2]) # slice step 2 index 0, 2, 4

print(nums[::-1]) # slice -> reverse

print(nums[-4:-2])
# inverted slice  -4 <end< =[2] to end -2 =[4]

# >> Slice a String << 
first_word = prompt[:4]
print(first_word)
# Output Tell

# Sting Length -> x = len(str)
print(len(infos))

# lower() capitalize upper()
first_word = first_word.lower()
print(first_word)
first_word = first_word.capitalize()
print(first_word)
first_word = first_word.upper()
print(first_word)

# Query in a string
print("Tell" in prompt) # True

idx_q = prompt.find("Tell") #
print(idx_q)

cnt_q = prompt.count("Tell") #

# Replace a String
wlcm = "Welcome to ML"
replaced_wlcm = wlcm.replace("ML", "AI/ML")
print(wlcm)
print(replaced_wlcm)

# %%
# Tokenize (Splitting, Joining & Formatting)

# Split
prompt = "What is Phitron ?"

tokens = prompt.split()
print(tokens)

# Join
sentence = "-".join(tokens)
print(type(sentence))
print(sentence)

# Formatting
name = "Adice"
age = 23
height = 5.1123445
formatted = f"Her name is: {name.upper}.\n She is {age} years old.\n She is {height:.3} feet\n"
print(formatted)
model_accuracy = 0.83333
print(f"Model Accuracy: {model_accuracy}")

# %%
# Lists in Python
nums = [100,20,30,40,50]
fl_nums = [10.20,3,15,2.4,2.7,3.5]
fruit = ['apple','orange','lichi']
mix = [10, 10.20, 'apple']
print(nums[2]) # 30
nums[2] = 90
print(nums[2]) # 90

# slice a new list
new_list = nums[0:3]
print(new_list)

# Append
nums.append(80)
print(nums)

# Insert
nums.insert(0,45)
print(nums)

# Delete pop, remove 
# pop() <- delete last value
nums.pop()
print(nums)
# remove() <- delete a specifi value
nums.remove(100)
print(nums)

# Sort, Reverse
nums.sort()
print(nums)

nums.reverse()
print(nums)

# %%
# Lists as Stacks and Queue in Python
# Stacks
stack = []
print(type(stack))
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)
print(stack)

print(stack.pop())
a = stack.pop()
print(stack, a)
stack.append(a)
print(stack)

# =>.top() getting top element 1
a = stack[-1]
print(f"top element {stack[-1]}")

# =>.pop() delete and get top element
s = stack.pop()
print(f"actual top element {stack[-1]}, old was {s}")

# Queue
def que():
    queue = []
    queue.append(1)
    queue.append(2)
    queue.append(3)
    queue.append(4)
    queue.append(5)
    return queue
# =>.push() push a value in queue
def q_push(queue, q):
    queue.append(q)
    print(f"front element: {queue1[0]}")

# =>.front() accessing front element
def q_front(queue):
    q = queue[0]
    print(f"front element: {queue1[0]}")
    return q
# =>.pop() delete and get top element
def q_pop(queue):
    q = queue.pop()
    print(f"actual front element {queue[0]}, old was {q}")
    return q
# calls

queue1 = que()
print(queue1)

q_push(queue1, 10)
print("Updated queue: ", queue1)

print(f"q_front call returned value: {q_front(queue1)}")
print("Updated queue: ", queue1)

print(f"q_pop call returned value: {q_pop(queue1)}")
print("Updated queue: ", queue1)

# %%
# List Comprehension

even = []
for i in range(101):
    if i%2 == 0:
        even.append(i)
print(even)

# Random List

rnd = [x+10 for x in range(10) if i%2 != 0]

print(rnd)

# List of Strings Comprehension

fruits = ['apple','orange','lichi']
upper_fruits = []

for fruit in fruits:
    upper_fruits.append(fruit.upper())
print(upper_fruits)

upper_fruits2 = [fruit.lower() for fruit in fruits]
